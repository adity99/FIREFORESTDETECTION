# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Set parameters
base_dir = 'lab2_dataset'
img_height, img_width = 150, 150
batch_size = 32
num_classes = 4 # Update based on your classes

# %%
# Load dataset
classes = ['smokefire','smoke','nofire','fire']
data = []
labels = []
for label in classes:
    folder_path = os.path.join(base_dir, label)
    for filename in os.listdir(folder_path):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            img_path = os.path.join(folder_path, filename)
            img = load_img(img_path, target_size=(img_height, img_width))
            img_array = img_to_array(img) / 255.0  # Normalize to [0, 1]
            data.append(img_array)
            labels.append(classes.index(label))

data = np.array(data)
labels = np.array(labels)

# %%
print(f"Data shape: {data.shape}")
print(f"Labels shape: {labels.shape}")
# Out:
# Data shape: (800, 150, 150, 3)
# Labels shape: (800,)

# %%
# Split dataset
X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, random_state=42, stratify=labels)

# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator()
train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
val_generator = val_datagen.flow(X_val, y_val, batch_size=batch_size)

# %%
# Load DenseNet121 model
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))
base_model.trainable = True  # Unfreeze the entire model initially

# Add custom layers on top of DenseNet121
x = base_model.output
x = Flatten()(x)
x = Dense(256, activation='relu')(x)  # Increased layer size
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)  # Additional dense layer
x = Dropout(0.5)(x)
predictions = Dense(num_classes, activation='softmax')(x)

# %%
# Create final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile model with a lower learning rate
optimizer = Adam(learning_rate=1e-4)  # Lower learning rate
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train model
history = model.fit(train_generator,
                    validation_data=val_generator,
                    epochs=10,  # Increased epochs
                    verbose=1)
# Out:
# Epoch 1/10
# C:\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 108s 3s/step - accuracy: 0.3219 - loss: 2.4714 - val_accuracy: 0.6125 - val_loss: 1.0019
# Epoch 2/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - accuracy: 0.5002 - loss: 1.3400 - val_accuracy: 0.7937 - val_loss: 0.6778
# Epoch 3/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.6509 - loss: 0.8664 - val_accuracy: 0.8188 - val_loss: 0.4723
# Epoch 4/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.7207 - loss: 0.6839 - val_accuracy: 0.8438 - val_loss: 0.3712
# Epoch 5/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.7484 - loss: 0.5803 - val_accuracy: 0.8813 - val_loss: 0.3420
# Epoch 6/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.7944 - loss: 0.5988 - val_accuracy: 0.8938 - val_loss: 0.2980
# Epoch 7/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.7817 - loss: 0.5394 - val_accuracy: 0.9125 - val_loss: 0.2694
# Epoch 8/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.8169 - loss: 0.4312 - val_accuracy: 0.9250 - val_loss: 0.2461
# Epoch 9/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.8488 - loss: 0.3817 - val_accuracy: 0.9312 - val_loss: 0.2396
# Epoch 10/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.8846 - loss: 0.3057 - val_accuracy: 0.9250 - val_loss: 0.2782

# %%
# Evaluate the model on the validation set
loss, accuracy = model.evaluate(X_val, y_val, verbose=0)
print(f"Validation Accuracy: {accuracy:.4f}")
print(f"Validation Loss: {loss:.4f}")
# Out:
# Validation Accuracy: 0.9250
# Validation Loss: 0.2782

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Predict the labels for the validation set
y_pred = model.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate classification report
print("Classification Report:")
print(classification_report(y_val, y_pred_classes, target_names=classes))

# Generate confusion matrix
conf_matrix = confusion_matrix(y_val, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 500ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#    smokefire       0.83      0.97      0.90        40
#        smoke       0.97      0.82      0.89        40
#       nofire       1.00      0.93      0.96        40
#         fire       0.93      0.97      0.95        40
#
#     accuracy                           0.93       160
#    macro avg       0.93      0.92      0.93       160
# weighted avg       0.93      0.93      0.93       160

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
import random
import matplotlib.pyplot as plt

# Function to predict and visualize random images
def predict_and_visualize_random_images(base_dir, model, img_height, img_width, classes, num_images=15):
    # Select random images from the base directory
    random_images = []
    for _ in range(num_images):
        random_class = random.choice(classes)
        folder_path = os.path.join(base_dir, random_class)
        random_file = random.choice(os.listdir(folder_path))
        img_path = os.path.join(folder_path, random_file)
        random_images.append((img_path, random_class))

    # Plot the images with predictions
    plt.figure(figsize=(20, 20))
    for i, (img_path, true_class) in enumerate(random_images):
        # Load and preprocess the image
        img = load_img(img_path, target_size=(img_height, img_width))
        img_array = img_to_array(img) / 255.0  # Normalize to [0, 1]
        img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

        # Predict the class
        prediction = model.predict(img_array)
        predicted_class = classes[np.argmax(prediction)]

        # Display the image with true and predicted labels
        plt.subplot(3, 5, i + 1)  # 3 rows, 5 columns
        plt.imshow(img)
        plt.title(f"True: {true_class}\nPred: {predicted_class}")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Call the function to visualize 15 predictions
predict_and_visualize_random_images(base_dir, model, img_height, img_width, classes, num_images=15)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step

# %%
import os
print("Model successfully converted and saved as model.tflite.")
print("Current Working Directory:", os.getcwd())
# Out:
# Model successfully converted and saved as model.tflite.
# Current Working Directory: C:\Users\Rishi\Downloads

# %%
model.save('hello.keras')

# %%
import tensorflow as tf
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the converted model to a .tflite file
with open("model.tflite", 'wb') as f:
    f.write(tflite_model)

print("Model successfully converted and saved as model.tflite.")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Rishi\AppData\Local\Temp\tmpmkeyye3r\assets
# INFO:tensorflow:Assets written to: C:\Users\Rishi\AppData\Local\Temp\tmpmkeyye3r\assets
# Saved artifact at 'C:\Users\Rishi\AppData\Local\Temp\tmpmkeyye3r'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   2939906658704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906661200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906660432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906656400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906659856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906659664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906660048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906660240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906662736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906663504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906662544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906664464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906664080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906663696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906666768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906666192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906666576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906664848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906667728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906668688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906666960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906667344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906668496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906668880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555379728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555378960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2939906669648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555378768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555380112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555381456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555381648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555381264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555380496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555382032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555383376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555383568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555383184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555382416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555383952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555385296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555385488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555385104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555384336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555382800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555387408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555387600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555387216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555379536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555386256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555389520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555389712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555389328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555386832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555390096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555391440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555391632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555391248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555390480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555392016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555393360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555393552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555393168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555392400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555393936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555394320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555821712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555388944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555392784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555821904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555823248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555823440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555823056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555822288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555823824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555825168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555825360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555824976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555824208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555825744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555827088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555827280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555826896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555826128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555827664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555829008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555829200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555828816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555828048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555829584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555830928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555831120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555830736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555829968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555831504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555832848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555833040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555832656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555831888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555833424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555834768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555834960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555834576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555833808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555835344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555836688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555836880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555836496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555835728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940555834192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556248272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556247120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556248080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556248464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556248848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556250192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556250384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556250000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556249232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556250768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556252112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556252304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556251920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556251152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556252688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556254032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556254224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556253840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556253072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556254608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556255952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556256144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556255760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556254992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556256528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556257872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556258064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556257680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556256912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556258448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556259792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556259984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556259600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556258832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556260368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556261712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556261904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556261520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556260752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556262288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556262672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556674256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556247696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556261136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556674064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556675216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556675408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556675024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556673296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556675792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556677136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556677328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556676944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556676176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556677712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556679056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556679248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556678864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556678096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556679632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556680976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556681168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556680784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556680016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556681552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556682896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556683088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556682704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556681936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556683472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556684816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556685008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556684624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556683856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556685392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556686736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556686928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556686544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556685776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556687312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556688656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556688848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556688464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556687696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940556686160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557198160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557197392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557198352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557197584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557199120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557200464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557200656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557200272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557199504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557201040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557202384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557202576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557202192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557201424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557202960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557204304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557204496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557204112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557203344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557204880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557206224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940557206416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2940